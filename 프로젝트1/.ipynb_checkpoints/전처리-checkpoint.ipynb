# %%
import pandas as pd

file_path = "01_Data.csv"

df = pd.read_csv(file_path)

df.info(), df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51301 entries, 0 to 51300
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          51301 non-null  int64
#  1   Member_ID      51301 non-null  int64
#  2   Sales_Type     51301 non-null  object
#  3   Contract_Type  51301 non-null  object
#  4   Channel        51301 non-null  object
#  5   Datetime       51301 non-null  object
#  6   Term           51301 non-null  int64
#  7   Payment_Type   51301 non-null  object
#  8   Product_Type   51301 non-null  object
#  9   Amount_Month   51301 non-null  int64
#  10  Customer_Type  51299 non-null  object
#  11  Age            44329 non-null  float64
#  12  Address1       51299 non-null  object
#  13  Address2       51299 non-null  object
#  14  State          51301 non-null  object
#  15  Overdue_count  51301 non-null  int64
#  16  Overdue_Type   51301 non-null  object
#  17  Gender         51301 non-null  object
#  18  Credit_Rank    42520 non-null  float64
#  19  Bank           48542 non-null  object
# dtypes: float64(2), int64(5), object(13)
# memory usage: 7.8+ MB
# (None,
#                Index     Member_ID          Term   Amount_Month           Age  \
#  count  51301.000000  5.130100e+04  51301.000000   51301.000000  44329.000000
#  mean   25651.703612  6.266432e+07     55.639149   93994.974289     50.024093
#  std    14809.828628  1.216146e+07     12.009915   15304.263988     10.983877
#  min        1.000000  2.568798e+07     12.000000   54603.000000     25.000000
#  25%    12826.000000  6.643148e+07     60.000000   81900.000000     42.000000
#  50%    25652.000000  6.676578e+07     60.000000   96900.000000     49.000000
#  75%    38477.000000  6.678160e+07     60.000000   98400.000000     57.000000
#  max    51302.000000  6.696986e+07     60.000000  215700.000000    102.000000
#
#         Overdue_count   Credit_Rank
#  count   51301.000000  42520.000000
#  mean        0.161381      3.428810
#  std         1.122193      2.213453
#  min         0.000000      0.000000
#  25%         0.000000      1.000000
#  50%         0.000000      3.000000
#  75%         0.000000      5.000000
#  max        15.000000     10.000000  )

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >

# %%
df_cleaned = df.set_index("Index")

# %%
df_cleaned = df_cleaned.drop(['Member_ID','Address1'], axis = 1)

# %%
df_cleaned['Datetime'] = pd.to_datetime(df_cleaned['Datetime'])

# %%
df_cleaned.isnull().sum()
# Out:
# Sales_Type          0
# Contract_Type       0
# Channel             0
# Datetime            0
# Term                0
# Payment_Type        0
# Product_Type        0
# Amount_Month        0
# Customer_Type       2
# Age              6972
# Address2            2
# State               0
# Overdue_count       0
# Overdue_Type        0
# Gender              0
# Credit_Rank      8781
# Bank             2759
# dtype: int64

# %%
df_cleaned = df_cleaned.dropna(subset=['Customer_Type', 'Address2'])
df_cleaned['Bank'] = df_cleaned['Bank'].fillna('Unknown') 
df_cleaned['Age'] = df_cleaned['Age'].fillna(df_cleaned['Age'].mean())

df_cleaned
# Out:
#       Sales_Type Contract_Type Channel   Datetime  Term Payment_Type  \
# Index
# 1             렌탈          일반계약    영업방판 2022-05-05    60          CMS
# 2             렌탈          교체계약    영업방판 2023-02-19    60         카드이체
# 3             렌탈          일반계약  홈쇼핑/방송 2022-02-27    60          CMS
# 4            멤버십        멤버십3유형     재계약 2022-05-12    12          CMS
# 5            멤버십        멤버십3유형     재계약 2022-05-09    12          CMS
# ...          ...           ...     ...        ...   ...          ...
# 51298         렌탈        프로모션계약   대형마트A 2022-02-28    60          CMS
# 51299         렌탈          일반계약   대형마트A 2022-03-31    60          CMS
# 51300         렌탈        프로모션계약    영업방판 2022-03-31    39         카드이체
# 51301         렌탈          일반계약  홈쇼핑/방송 2023-02-05    60         카드이체
# 51302         렌탈          일반계약  홈쇼핑/방송 2022-04-23    60          CMS
#
#       Product_Type  Amount_Month Customer_Type   Age Address2 State  \
# Index
# 1            DES-1         96900            개인  42.0      경기도  계약확정
# 2            DES-1        102900            개인  39.0      경기도  계약확정
# 3            DES-1         96900            개인  48.0      경기도  계약확정
# 4            DES-1         66900            개인  39.0      경기도  계약확정
# 5            DES-1         66900            개인  60.0      경기도  기간만료
# ...            ...           ...           ...   ...      ...   ...
# 51298       DES-3A         96900            개인  47.0      경기도  계약확정
# 51299        DES-1         96900            개인  42.0      경기도  계약확정
# 51300          ERA        120900            개인  65.0    서울특별시  계약확정
# 51301        DES-1         96900            개인  54.0    서울특별시  계약확정
# 51302        DES-1         96900            개인  53.0    서울특별시  계약확정
#
#        Overdue_count Overdue_Type Gender  Credit_Rank    Bank
# Index
# 1                  0           없음     여자          9.0   새마을금고
# 2                  0           없음     남자          2.0    현대카드
# 3                  0           없음     여자          8.0    우리은행
# 4                  0           없음     남자          5.0  농협회원조합
# 5                 12           있음     남자          8.0  농협회원조합
# ...              ...          ...    ...          ...     ...
# 51298              0           없음     남자          NaN    기업은행
# 51299              0           없음     여자          8.0   새마을금고
# 51300              0           없음     여자          1.0    롯데카드
# 51301              0           없음     여자          2.0    롯데카드
# 51302              0           없음     여자          8.0    신한은행
#
# [51299 rows x 17 columns]

# %%
df_cleaned.loc[df_cleaned['Overdue_Type'] == '있음', 'Credit_Rank'] = df_cleaned['Credit_Rank'].fillna(7)
df_cleaned.loc[df_cleaned['Overdue_Type'] != '있음', 'Credit_Rank'] = df_cleaned['Credit_Rank'].fillna(5)

df_cleaned
# Out:
#       Sales_Type Contract_Type Channel   Datetime  Term Payment_Type  \
# Index
# 1             렌탈          일반계약    영업방판 2022-05-05    60          CMS
# 2             렌탈          교체계약    영업방판 2023-02-19    60         카드이체
# 3             렌탈          일반계약  홈쇼핑/방송 2022-02-27    60          CMS
# 4            멤버십        멤버십3유형     재계약 2022-05-12    12          CMS
# 5            멤버십        멤버십3유형     재계약 2022-05-09    12          CMS
# ...          ...           ...     ...        ...   ...          ...
# 51298         렌탈        프로모션계약   대형마트A 2022-02-28    60          CMS
# 51299         렌탈          일반계약   대형마트A 2022-03-31    60          CMS
# 51300         렌탈        프로모션계약    영업방판 2022-03-31    39         카드이체
# 51301         렌탈          일반계약  홈쇼핑/방송 2023-02-05    60         카드이체
# 51302         렌탈          일반계약  홈쇼핑/방송 2022-04-23    60          CMS
#
#       Product_Type  Amount_Month Customer_Type   Age Address2 State  \
# Index
# 1            DES-1         96900            개인  42.0      경기도  계약확정
# 2            DES-1        102900            개인  39.0      경기도  계약확정
# 3            DES-1         96900            개인  48.0      경기도  계약확정
# 4            DES-1         66900            개인  39.0      경기도  계약확정
# 5            DES-1         66900            개인  60.0      경기도  기간만료
# ...            ...           ...           ...   ...      ...   ...
# 51298       DES-3A         96900            개인  47.0      경기도  계약확정
# 51299        DES-1         96900            개인  42.0      경기도  계약확정
# 51300          ERA        120900            개인  65.0    서울특별시  계약확정
# 51301        DES-1         96900            개인  54.0    서울특별시  계약확정
# 51302        DES-1         96900            개인  53.0    서울특별시  계약확정
#
#        Overdue_count Overdue_Type Gender  Credit_Rank    Bank
# Index
# 1                  0           없음     여자          9.0   새마을금고
# 2                  0           없음     남자          2.0    현대카드
# 3                  0           없음     여자          8.0    우리은행
# 4                  0           없음     남자          5.0  농협회원조합
# 5                 12           있음     남자          8.0  농협회원조합
# ...              ...          ...    ...          ...     ...
# 51298              0           없음     남자          5.0    기업은행
# 51299              0           없음     여자          8.0   새마을금고
# 51300              0           없음     여자          1.0    롯데카드
# 51301              0           없음     여자          2.0    롯데카드
# 51302              0           없음     여자          8.0    신한은행
#
# [51299 rows x 17 columns]

# %%
df_cleaned.isnull().sum()
# Out:
# Sales_Type       0
# Contract_Type    0
# Channel          0
# Datetime         0
# Term             0
# Payment_Type     0
# Product_Type     0
# Amount_Month     0
# Customer_Type    0
# Age              0
# Address2         0
# State            0
# Overdue_count    0
# Overdue_Type     0
# Gender           0
# Credit_Rank      0
# Bank             0
# dtype: int64

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51299 entries, 1 to 51302
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales_Type     51299 non-null  object
#  1   Contract_Type  51299 non-null  object
#  2   Channel        51299 non-null  object
#  3   Datetime       51299 non-null  datetime64[ns]
#  4   Term           51299 non-null  int64
#  5   Payment_Type   51299 non-null  object
#  6   Product_Type   51299 non-null  object
#  7   Amount_Month   51299 non-null  int64
#  8   Customer_Type  51299 non-null  object
#  9   Age            51299 non-null  float64
#  10  Address2       51299 non-null  object
#  11  State          51299 non-null  object
#  12  Overdue_count  51299 non-null  int64
#  13  Overdue_Type   51299 non-null  object
#  14  Gender         51299 non-null  object
#  15  Credit_Rank    51299 non-null  float64
#  16  Bank           51299 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(11)
# memory usage: 9.1+ MB

# %%
df_cleaned["Channel"] = df_cleaned["Channel"].replace({
    '대형마트A': '대형마트', '대형마트C': '대형마트', '대형마트H': '대형마트',
    '대형마트N': '대형마트', '대형마트E': '대형마트',
    '영업방판': '영업방판',
    '자체홈페이지': '홈쇼핑', '홈쇼핑/방송': '홈쇼핑', '홈쇼핑/인터넷': '홈쇼핑',
    '전단홍보': '전단홍보',
    '전문매장H': '전문매장', '전문매장Z': '전문매장',
    '직영유통사': '직영사', '직영계열사A': '직영사', '직영계열사B': '직영사',
    '재계약': '재계약'
})
df_cleaned
# Out:
#       Sales_Type Contract_Type Channel   Datetime  Term Payment_Type  \
# Index
# 1             렌탈          일반계약    영업방판 2022-05-05    60          CMS
# 2             렌탈          교체계약    영업방판 2023-02-19    60         카드이체
# 3             렌탈          일반계약     홈쇼핑 2022-02-27    60          CMS
# 4            멤버십        멤버십3유형     재계약 2022-05-12    12          CMS
# 5            멤버십        멤버십3유형     재계약 2022-05-09    12          CMS
# ...          ...           ...     ...        ...   ...          ...
# 51298         렌탈        프로모션계약    대형마트 2022-02-28    60          CMS
# 51299         렌탈          일반계약    대형마트 2022-03-31    60          CMS
# 51300         렌탈        프로모션계약    영업방판 2022-03-31    39         카드이체
# 51301         렌탈          일반계약     홈쇼핑 2023-02-05    60         카드이체
# 51302         렌탈          일반계약     홈쇼핑 2022-04-23    60          CMS
#
#       Product_Type  Amount_Month Customer_Type   Age Address2 State  \
# Index
# 1            DES-1         96900            개인  42.0      경기도  계약확정
# 2            DES-1        102900            개인  39.0      경기도  계약확정
# 3            DES-1         96900            개인  48.0      경기도  계약확정
# 4            DES-1         66900            개인  39.0      경기도  계약확정
# 5            DES-1         66900            개인  60.0      경기도  기간만료
# ...            ...           ...           ...   ...      ...   ...
# 51298       DES-3A         96900            개인  47.0      경기도  계약확정
# 51299        DES-1         96900            개인  42.0      경기도  계약확정
# 51300          ERA        120900            개인  65.0    서울특별시  계약확정
# 51301        DES-1         96900            개인  54.0    서울특별시  계약확정
# 51302        DES-1         96900            개인  53.0    서울특별시  계약확정
#
#        Overdue_count Overdue_Type Gender  Credit_Rank    Bank
# Index
# 1                  0           없음     여자          9.0   새마을금고
# 2                  0           없음     남자          2.0    현대카드
# 3                  0           없음     여자          8.0    우리은행
# 4                  0           없음     남자          5.0  농협회원조합
# 5                 12           있음     남자          8.0  농협회원조합
# ...              ...          ...    ...          ...     ...
# 51298              0           없음     남자          5.0    기업은행
# 51299              0           없음     여자          8.0   새마을금고
# 51300              0           없음     여자          1.0    롯데카드
# 51301              0           없음     여자          2.0    롯데카드
# 51302              0           없음     여자          8.0    신한은행
#
# [51299 rows x 17 columns]
